# %%
import schemdraw

import sdcomms as comms

schemdraw.use("matplotlib")


def drawElements(elm_list, n=5, dx=1, dy=2, ofst=0.8, fname=None, **kwargs):
    x, y = 0, 0
    d = schemdraw.Drawing(fontsize=12)
    for e in elm_list:
        element = getattr(comms, e)
        d += element().at(((d.unit + 1) * x + 1, y))
        x = x + dx
        if x >= n:
            x = 0
            y = y - dy
    return d


elems = [
    "Rectangle",
    "CouplerDot",
    "CouplerCirc",
    "BS",
    "Fiber",
    "PolCtrl",
    "VOA",
    "PM",
    "MZM",
    "IQM",
    "OSA",
    "ESA",
    "AWG",
    "Scope",
    "OPM",
    "PD",
    "LD",
    "Circle",
    "Square",
    # "Arrow",
    # "Line",
    "Filter",
    "Amp",
    "Circulator",
    "Adc",
    "Dac",
    "MUX",
    # "ArcZ",z
]

schemdraw.config(lw=1)
display(drawElements(elems, d="right"))

# %%
with schemdraw.Drawing() as d:
    comms.Circulator().scale(5).linewidth(7)
